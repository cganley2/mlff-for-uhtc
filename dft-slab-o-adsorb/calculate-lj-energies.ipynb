# %%
import ase
from ase import io
from ase.visualize import view
from ase.calculators.lj import LennardJones
from ase.calculators.morse import MorsePotential
from ase.visualize import view

# %%
H = ase.io.read('H/zrb2-o-H-relax.in')
B = ase.io.read('B/zrb2-o-B-relax.in')
T = ase.io.read('T/zrb2-o-T-relax.in')

# %%
# H.calc = LennardJones()
# B.calc = LennardJones()
# T.calc = LennardJones()
H.calc = MorsePotential()
B.calc = MorsePotential()
T.calc = MorsePotential()

# %%
H.get_potential_energy()
# view(H)
# Out:
# np.float64(-1.9110511121904374)

# %%
B.get_potential_energy()
# view(B)
# Out:
# np.float64(-1.9511015544168622)

# %%
T.get_potential_energy()
# view(T)
# Out:
# np.float64(-2.0076045153283393)
# X connection to localhost:10.0 broken (explicit kill or server shutdown).
# X connection to localhost:10.0 broken (explicit kill or server shutdown).
